# %%
#W6A1
(lambda a: print(list(a[i] for i in range(len(a)) if (not i or a[i] not in a[:i]))))(list(map(int, input().split())))
# Out:
# [1, 2, 3, 4, 5]

# %%
#W6A2
(lambda a: print(list(sum(a[:i + 1]) for i in range(len(a)))))(list(map(int, input().split())))
# Out:
# [10, 5, 15]

# %%
#W6A3
(lambda a, k: print(tuple(a[k % len(a):] + a[:k % len(a)])))(list(map(int, input().split())), int(input()))
# Out:
# (5, 6)

# %%
#W6A4
(lambda a: print({i[:i.index(':')]: list(j[j.index(':') + 1:] for j in a if j[:j.index(':')] == i[:i.index(':')]) for i in a}))(input().split())
# Out:
# {'name': ['Alice', 'Bob'], 'age': ['20']}

# %%
#W6A5
(lambda a: print({'positives': sum((i > 0) for i in a), 'negatives': sum((i < 0) for i in a), 'zeros': sum((i == 0) for i in a)}))(list(map(int, input().split())))
# Out:
# {'positives': 2, 'negatives': 2, 'zeros': 3}

# %%
#W6A6
print(sum(map(int, input().split())))
# Out:
# 600

# %%
#W6A7
(lambda a: print(f"{a[0]} {a[-1]}", tuple(a[::-1])))(input().split())
# Out:
# a c ('c', 'b', 'a')

# %%
#W6A8
(lambda a: print({i: sum((j == i) for j in a) for i in a}))(input().split())
# Out:
# {'1': 3, '2': 2, '3': 1}

# %%
#W6A9
(lambda a: print(dict(sorted({i[:i.index(':')].strip().strip("'") : sum(int(j[j.index(':') + 1:]) for j in a if (j[:j.index(':')].strip().strip("'") == i[:i.index(':')].strip().strip("'"))) for i in a}.items()))))(list(i for i in (input()[1: -1] + ',' + input()[1: -1]).split(',') if i))
# Out:
# {'k': 5, 'm': 2, 'n': 3}

# %%
#W6A10
(lambda a, k: print(list((i, k - i) for i in sorted(set(k - a[j] for j in range(1, len(a)) if k - a[j] in a[:j])))))(list(map(int, input().split())), int(input()))
# Out:
# [(1, 3), (2, 2), (3, 1)]

# %%
#W6A11
(lambda a: print(tuple(i for i in a if not (i & 1)), tuple(i for i in a if (i & 1)), sep='\n'))(list(map(int, input().split())))
# Out:
# (10, 2, 8, 4, 6)
# (1, 9, 3, 7, 5)

# %%
#W6A12
(lambda a: max(a) - max([[sum(1 for j in a if j == i), max(a) - i] for i in a])[1])(list(map(int, input().split())))
# Out:
# -3

# %%
#W6A13
(lambda a: print({a[i << 1 | 1]: a[i << 1] for i in range(len(a) >> 1)}))(input().split())
# Out:
# {'2': '1', '4': '3', '5': '4'}

# %%
#W6A14
(lambda a, b: (print(list(set(int(i) for i in a if i in b)))))(input().split(), input().split())
# Out:
# [4, 5]

# %%
#W6A15
(lambda a, k: print({a[i << 1]: int(a[i << 1 | 1]) for i in range(len(a) >> 1) if int(a[i << 1 | 1]) > k}))(input().split(), int(input()))
# Out:
# {'x': -5, 'z': -2}

# %%
#W6A19
(lambda a: print(a.index(max(a)) + 1))(list(map(int, input().split())))
# Out:
# 3

# %%
#W6A20
(lambda a, k: print(a.index(k) + 1 if k in a else -1))(input().split(), input())
# Out:
# -1

# %%
#W6A21
(lambda a: print({i: tuple(j for j in range(len(a)) if a[j] == i) for i in a}))(input().split())
# Out:
# {'1': (0, 1, 2)}
